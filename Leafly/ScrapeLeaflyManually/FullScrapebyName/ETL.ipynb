# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
all_files = []
for i in range(1,161):
    all_files.append('page{}_strain_data.csv'.format(i))

# %%
full_strain_df = pd.DataFrame()
for file in all_files:
    df = pd.read_csv(file)
    full_strain_df = full_strain_df.append(df, ignore_index=True)

# %%
full_strain_df.to_csv('full_strain_df.csv', index=False)

# %%
df = pd.read_csv('full_strain_df.csv')
df
# Out:
#                      strain         type      potency       rating  \
# 0             #9 Blackberry  Unavailable      THC 29%  Unavailable
# 1                   $100 OG       Hybrid  Unavailable          2.9
# 2     '98 Aloha White Widow       Hybrid  Unavailable          4.8
# 3                      1024       Sativa      THC 13%          4.5
# 4               10th Planet       Hybrid  Unavailable          4.7
# ...                     ...          ...          ...          ...
# 5086           Zurple Punch       Hybrid      THC 22%  Unavailable
# 5087         Zweet Insanity  Unavailable      THC 26%  Unavailable
# 5088            hai Fantasy       Hybrid  Unavailable          1.0
# 5089            ʻAlenuihāhā       Hybrid  Unavailable          5.0
# 5090      ‘88 G13 Hashplant       Hybrid      THC 19%          4.8
#
#      review_count                                            reports  \
# 0     Unavailable                                        Unavailable
# 1           (508)  332 people reported 2198 effectsThis info is s...
# 2            (15)  10 people reported 42 effectsThis info is sour...
# 3            (61)  37 people reported 206 effectsThis info is sou...
# 4            (11)  8 people reported 45 effectsThis info is sourc...
# ...           ...                                                ...
# 5086  Unavailable                                        Unavailable
# 5087  Unavailable                                        Unavailable
# 5088          (1)                                        Unavailable
# 5089          (7)  4 people reported 29 effectsThis info is sourc...
# 5090          (5)  2 people reported 27 effectsThis info is sourc...
#
#                                           Anxiety   \
# 0                                              NaN
# 1      ['46% of people say it helps with anxiety']
# 2                                              NaN
# 3      ['16% of people say it helps with anxiety']
# 4                                              NaN
# ...                                            ...
# 5086                                           NaN
# 5087                                           NaN
# 5088                                           NaN
# 5089                                           NaN
# 5090  ['100% of people say it helps with anxiety']
#
#                                        Creative   \
# 0                                            NaN
# 1      ['38% of people report feeling creative']
# 2                                            NaN
# 3      ['29% of people report feeling creative']
# 4                                            NaN
# ...                                          ...
# 5086                                         NaN
# 5087                                         NaN
# 5088                                         NaN
# 5089  ['100% of people report feeling creative']
# 5090                                         NaN
#
#                                          Depression   \
# 0                                                NaN
# 1     ['24% of people say it helps with depression']
# 2                                                NaN
# 3     ['13% of people say it helps with depression']
# 4     ['12% of people say it helps with depression']
# ...                                              ...
# 5086                                             NaN
# 5087                                             NaN
# 5088                                             NaN
# 5089                                             NaN
# 5090  ['50% of people say it helps with depression']
#
#                                       Dizzy   ... Tourette's syndrome   \
# 0                                        NaN  ...                  NaN
# 1     ['13% of people report feeling dizzy']  ...                  NaN
# 2                                        NaN  ...                  NaN
# 3      ['5% of people report feeling dizzy']  ...                  NaN
# 4                                        NaN  ...                  NaN
# ...                                      ...  ...                  ...
# 5086                                     NaN  ...                  NaN
# 5087                                     NaN  ...                  NaN
# 5088                                     NaN  ...                  NaN
# 5089                                     NaN  ...                  NaN
# 5090                                     NaN  ...                  NaN
#
#      Anorexia  Tinnitus  Cancer  Muscular dystrophy  Phantom limb pain   \
# 0          NaN       NaN     NaN                 NaN                NaN
# 1          NaN       NaN     NaN                 NaN                NaN
# 2          NaN       NaN     NaN                 NaN                NaN
# 3          NaN       NaN     NaN                 NaN                NaN
# 4          NaN       NaN     NaN                 NaN                NaN
# ...        ...       ...     ...                 ...                ...
# 5086       NaN       NaN     NaN                 NaN                NaN
# 5087       NaN       NaN     NaN                 NaN                NaN
# 5088       NaN       NaN     NaN                 NaN                NaN
# 5089       NaN       NaN     NaN                 NaN                NaN
# 5090       NaN       NaN     NaN                 NaN                NaN
#
#      Hypertension  Crohn's disease  Glaucoma  HIV/AIDS
# 0              NaN              NaN       NaN       NaN
# 1              NaN              NaN       NaN       NaN
# 2              NaN              NaN       NaN       NaN
# 3              NaN              NaN       NaN       NaN
# 4              NaN              NaN       NaN       NaN
# ...            ...              ...       ...       ...
# 5086           NaN              NaN       NaN       NaN
# 5087           NaN              NaN       NaN       NaN
# 5088           NaN              NaN       NaN       NaN
# 5089           NaN              NaN       NaN       NaN
# 5090           NaN              NaN       NaN       NaN
#
# [5091 rows x 64 columns]
