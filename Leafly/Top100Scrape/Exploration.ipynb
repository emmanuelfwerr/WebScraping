# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

strain_data = pd.read_csv('top100strains.csv')

# review_count wrangling
strain_data['review_count'] = strain_data['review_count'].str.replace('(', '') 
strain_data['review_count'] = strain_data['review_count'].str.replace(')', '') 
strain_data['review_count'] = strain_data['review_count'].astype(int)

# rating wrangling
strain_data['rating'] = strain_data['rating'].astype(float)

# potency wrangling
strain_data['potency'] = strain_data['potency'].str.replace('THC', '') 
strain_data['potency'] = strain_data['potency'].str.replace('CBD', '')
strain_data['potency'] = strain_data['potency'].str.replace('%', '') 
strain_data['potency'] = strain_data['potency'].astype(int)

# output test
print(strain_data.head())

# description test
strain_data.dtypes

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

strain_data = pd.read_csv('top100strains.csv')

# output test
print(strain_data.head())

# description test
strain_data.dtypes
# Out:
#           strain    type  potency  rating review_count  \
# 0    9 lb Hammer  Indica  THC 18%     4.6        (948)
# 1  Acapulco Gold  Sativa  THC 18%     4.5        (645)
# 2           ACDC  Hybrid  CBD 14%     4.5        (788)
# 3        Afghani  Indica  THC 16%     4.3        (616)
# 4          Afgoo  Indica  THC 16%     4.0        (637)
#
#                                       Anxiety   \
# 0  ['22% of people say it helps with anxiety']
# 1  ['25% of people say it helps with anxiety']
# 2  ['36% of people say it helps with anxiety']
# 3  ['30% of people say it helps with anxiety']
# 4  ['29% of people say it helps with anxiety']
#
#                                   Anxious   \
# 0  ['1% of people report feeling anxious']
# 1  ['4% of people report feeling anxious']
# 2  ['2% of people report feeling anxious']
# 3                                      NaN
# 4                                      NaN
#
#                                       Depression   \
# 0  ['19% of people say it helps with depression']
# 1  ['28% of people say it helps with depression']
# 2  ['23% of people say it helps with depression']
# 3  ['18% of people say it helps with depression']
# 4  ['20% of people say it helps with depression']
#
#                                   Dizzy   \
# 0  ['3% of people report feeling dizzy']
# 1  ['4% of people report feeling dizzy']
# 2  ['2% of people report feeling dizzy']
# 3  ['8% of people report feeling dizzy']
# 4  ['8% of people report feeling dizzy']
#
#                                    Dry eyes   ...  \
# 0   ['8% of people report feeling dry eyes']  ...
# 1  ['15% of people report feeling dry eyes']  ...
# 2   ['4% of people report feeling dry eyes']  ...
# 3  ['19% of people report feeling dry eyes']  ...
# 4  ['19% of people report feeling dry eyes']  ...
#
#                                    Focused   \
# 0                                       NaN
# 1                                       NaN
# 2  ['32% of people report feeling focused']
# 3                                       NaN
# 4                                       NaN
#
#                                       Inflammation  Giggly  Tingly  Nausea   \
# 0                                               NaN     NaN     NaN     NaN
# 1                                               NaN     NaN     NaN     NaN
# 2  ['25% of people say it helps with inflammation']     NaN     NaN     NaN
# 3                                               NaN     NaN     NaN     NaN
# 4                                               NaN     NaN     NaN     NaN
#
#   Lack of appetite  ADD/ADHD  Headaches  Talkative  Muscle spasms
# 0               NaN       NaN        NaN        NaN            NaN
# 1               NaN       NaN        NaN        NaN            NaN
# 2               NaN       NaN        NaN        NaN            NaN
# 3               NaN       NaN        NaN        NaN            NaN
# 4               NaN       NaN        NaN        NaN            NaN
#
# [5 rows x 35 columns]
# strain                object
# type                  object
# potency               object
# rating               float64
# review_count          object
# Anxiety               object
# Anxious               object
# Depression            object
# Dizzy                 object
# Dry eyes              object
# Dry mouth             object
# Euphoric              object
# Happy                 object
# Headache              object
# Hungry                object
# Insomnia              object
# Pain                  object
# Relaxed               object
# Sleepy                object
# Stress                object
# Creative              object
# Energetic             object
# Fatigue               object
# Paranoid              object
# Uplifted              object
# Focused               object
# Inflammation          object
# Giggly                object
# Tingly                object
# Nausea                object
# Lack of appetite      object
# ADD/ADHD              object
# Headaches             object
# Talkative             object
# Muscle spasms         object
# dtype: object

# %%
from names import strain_names_list, strain_links
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np
import collections

# Compile list of links to scrape
names = strain_names_list()
strain_links = strain_links(names)

# Initializing list of lists for DataFrame
cannabis_info = []
headers = ['strain', 'type', 'potency', 'rating', 'review_count', 'reports']
cannabis_effects_df = pd.DataFrame()

# Extract cannabis info from each page
for i in range(5):
    # Request HTML for each link
    source = requests.get(strain_links[i]).text
    soup = BeautifulSoup(source, 'lxml')
    # Extract Strain ID Card
    strain = soup.find('div', {'class':'py-sm'}).h1.text
    type = soup.find('span', {'class':'text-xs bg-leafly-white py-sm px-sm rounded'}).text
    potency = soup.find('span', {'class':'text-xs bg-deep-green-20 py-sm px-sm rounded'}).text
    rating = soup.find('span', {'class':'pr-xs'}).text
    review_count = soup.find('span', {'class':'pl-xs'}).text

    #Extract Effects Reported
    reports = soup.find('div', {'class':'flex items-center font-mono text-xs'}).text
    ratios = soup.findAll('span', {'class':'font-mono text-grey text-xs'})
    effects = soup.findAll('span', {'class':'font-bold font-headers text-sm'})

    # Fill cannabis_info[]
    temporary_strain_data = [strain, type, potency, rating, review_count, reports]
    cannabis_info.append(temporary_strain_data)

    effect_ratios = {}
    for i in range(len(ratios)):
        effect_ratios[effects[i].text] = [ratios[i].text]
        effect_ratios = collections.OrderedDict(sorted(effect_ratios.items()))

    cannabis_effects_df = cannabis_effects_df.append(effect_ratios, ignore_index=True)

# Create and fill DataFrame
cannabis_info_df = pd.DataFrame(cannabis_info, columns = headers)
all_info_df = pd.concat([cannabis_info_df, cannabis_effects_df], axis=1)

all_info_df.head()
# Out:
#           strain    type  potency rating review_count  \
# 0    9 lb Hammer  Indica  THC 18%    4.6        (948)
# 1  Acapulco Gold  Sativa  THC 18%    4.5        (645)
# 2           ACDC  Hybrid  CBD 14%    4.5        (788)
# 3        Afghani  Indica  THC 16%    4.3        (616)
# 4          Afgoo  Indica  THC 16%    4.0        (637)
#
#                                              reports  \
# 0  691 people reported 4199 effectsThis info is s...
# 1  430 people reported 3123 effectsThis info is s...
# 2  593 people reported 3908 effectsThis info is s...
# 3  434 people reported 3161 effectsThis info is s...
# 4  470 people reported 3292 effectsThis info is s...
#
#                                     Anxiety   \
# 0  [22% of people say it helps with anxiety]
# 1  [25% of people say it helps with anxiety]
# 2  [36% of people say it helps with anxiety]
# 3  [30% of people say it helps with anxiety]
# 4  [29% of people say it helps with anxiety]
#
#                                 Anxious   \
# 0  [1% of people report feeling anxious]
# 1  [4% of people report feeling anxious]
# 2  [2% of people report feeling anxious]
# 3                                    NaN
# 4                                    NaN
#
#                                     Depression   \
# 0  [19% of people say it helps with depression]
# 1  [28% of people say it helps with depression]
# 2  [23% of people say it helps with depression]
# 3  [18% of people say it helps with depression]
# 4  [20% of people say it helps with depression]
#
#                                 Dizzy   ...  \
# 0  [3% of people report feeling dizzy]  ...
# 1  [4% of people report feeling dizzy]  ...
# 2  [2% of people report feeling dizzy]  ...
# 3  [8% of people report feeling dizzy]  ...
# 4  [8% of people report feeling dizzy]  ...
#
#                                  Relaxed   \
# 0  [66% of people report feeling relaxed]
# 1                                     NaN
# 2  [63% of people report feeling relaxed]
# 3  [64% of people report feeling relaxed]
# 4  [51% of people report feeling relaxed]
#
#                                  Sleepy   \
# 0  [48% of people report feeling sleepy]
# 1                                    NaN
# 2                                    NaN
# 3  [54% of people report feeling sleepy]
# 4  [45% of people report feeling sleepy]
#
#                                     Stress   \
# 0  [28% of people say it helps with stress]
# 1  [34% of people say it helps with stress]
# 2  [38% of people say it helps with stress]
# 3  [36% of people say it helps with stress]
# 4  [39% of people say it helps with stress]
#
#                                  Creative   \
# 0                                      NaN
# 1  [42% of people report feeling creative]
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#                                  Energetic   \
# 0                                       NaN
# 1  [40% of people report feeling energetic]
# 2  [17% of people report feeling energetic]
# 3                                       NaN
# 4                                       NaN
#
#                                     Fatigue   \
# 0                                        NaN
# 1  [16% of people say it helps with fatigue]
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#                                 Paranoid   \
# 0                                     NaN
# 1  [5% of people report feeling paranoid]
# 2                                     NaN
# 3  [3% of people report feeling paranoid]
# 4  [5% of people report feeling paranoid]
#
#                                  Uplifted   \
# 0                                      NaN
# 1  [54% of people report feeling uplifted]
# 2  [34% of people report feeling uplifted]
# 3                                      NaN
# 4  [27% of people report feeling uplifted]
#
#                                  Focused   \
# 0                                     NaN
# 1                                     NaN
# 2  [32% of people report feeling focused]
# 3                                     NaN
# 4                                     NaN
#
#                                     Inflammation
# 0                                             NaN
# 1                                             NaN
# 2  [25% of people say it helps with inflammation]
# 3                                             NaN
# 4                                             NaN
#
# [5 rows x 28 columns]

# %%
all_info_df.describe()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1652, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1652, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1652, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1652, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1652, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1652, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1652, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1652, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1652, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1652, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1652, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1652, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1652, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1652, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1652, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1652, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1652, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1652, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1652, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1652, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1652, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1652, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
#          strain    type  potency rating review_count  \
# count         5       5        5      5            5
# unique        5       3        3      4            5
# top     Afghani  Indica  THC 16%    4.5        (616)
# freq          1       3        2      2            1
#
#                                                   reports  \
# count                                                   5
# unique                                                  5
# top     430 people reported 3123 effectsThis info is s...
# freq                                                    1
#
#                                          Anxiety   \
# count                                           5
# unique                                          5
# top     [36% of people say it helps with anxiety]
# freq                                            1
#
#                                      Anxious   \
# count                                       3
# unique                                      3
# top     [1% of people report feeling anxious]
# freq                                        1
#
#                                          Depression   \
# count                                              5
# unique                                             5
# top     [23% of people say it helps with depression]
# freq                                               1
#
#                                      Dizzy   ...  \
# count                                     5  ...
# unique                                    4  ...
# top     [8% of people report feeling dizzy]  ...
# freq                                      2  ...
#
#                                       Relaxed   \
# count                                        4
# unique                                       4
# top     [64% of people report feeling relaxed]
# freq                                         1
#
#                                       Sleepy   \
# count                                       3
# unique                                      3
# top     [48% of people report feeling sleepy]
# freq                                        1
#
#                                          Stress   \
# count                                          5
# unique                                         5
# top     [38% of people say it helps with stress]
# freq                                           1
#
#                                       Creative   \
# count                                         1
# unique                                        1
# top     [42% of people report feeling creative]
# freq                                          1
#
#                                       Energetic   \
# count                                          2
# unique                                         2
# top     [40% of people report feeling energetic]
# freq                                           1
#
#                                          Fatigue   \
# count                                           1
# unique                                          1
# top     [16% of people say it helps with fatigue]
# freq                                            1
#
#                                      Paranoid   \
# count                                        3
# unique                                       2
# top     [5% of people report feeling paranoid]
# freq                                         2
#
#                                       Uplifted   \
# count                                         3
# unique                                        3
# top     [54% of people report feeling uplifted]
# freq                                          1
#
#                                       Focused   \
# count                                        1
# unique                                       1
# top     [32% of people report feeling focused]
# freq                                         1
#
#                                          Inflammation
# count                                                1
# unique                                               1
# top     [25% of people say it helps with inflammation]
# freq                                                 1
#
# [4 rows x 28 columns]
